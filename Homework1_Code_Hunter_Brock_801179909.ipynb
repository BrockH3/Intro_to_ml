# %% [markdown]
# <a href="https://colab.research.google.com/github/BrockH3/Intro_to_ml/blob/main/Homework1_Code_Hunter_Brock_801179909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url='/content/drive/My Drive/Intro to ML/datasets/D3.csv'
df=pd.read_csv(url)     #import csv file to readable format in python

x1=df.values[:,0]       #input first column
x2=df.values[:,1]       #input second column
x3=df.values[:,2]       #input third column
y=df.values[:,3]        #input fourth column

#length for number of training samples
m=len(y)
n=len(x1)

#create feature matrix for operation
X_0 = np.ones((m,1))

X_1 = x1.reshape(m,1)
X_2 = x2.reshape(m,1)
X_3 = x3.reshape(m,1)

X1 = np.hstack((X_0,X_1))
X2 = np.hstack((X_0,X_2))
X3 = np.hstack((X_0,X_3))

theta = np.zeros(2)

# %%
#computes the loss of linear regression
def loss_function(x,y,theta):

  prediction = x.dot(theta)
  error = np.subtract(prediction,y)
  error_square = np.square(error)

  Out = 1/(2*m) * np.sum(error_square)

  return Out

# %%
cost1 = loss_function(X1,y,theta)
print('cost of x1 = ',cost1)
cost2 = loss_function(X2,y,theta)
print('cost of x2 = ',cost2)
cost3 = loss_function(X3,y,theta)
print(' cost of x3 = ', cost3)
# Out:
# cost of x1 =  5.524438459196242
# cost of x2 =  5.524438459196242
#  cost of x3 =  5.524438459196242

# %%
def gradient_descent(x,y,theta,alpha,iterations):
  #compute the gradient descent for the linear regression

  #alpha is learning rate

  m=len(y)
  cost_history = np.zeros(iterations)     #creates a matrix to store the history

  for i in range(iterations):
    predictions = x.dot(theta)            #x dot product theta
    errors = np.subtract(predictions, y)  #calculate error

    #calculates the sum function for gradient descent
    sum_delta = (alpha / m) * x.transpose().dot(errors)
    theta -= sum_delta
    cost_history[i] = loss_function(x, y, theta)

  return theta,cost_history

# %%
theta=[0.,0.]
iterations = 1000
alpha = 0.05

# %%
theta,cost_history = gradient_descent(X1,y,theta,alpha,iterations)

# %%
#scatter plot and linear regression plot for x1
plt.scatter(X1[:,1],y,color='red',marker='+',label ='X1 Data')
plt.plot(X1[:,1], X1.dot(theta), color='green', label='Linear Regression')

plt.grid(True)
plt.xlabel('X1')
plt.ylabel('y')
plt.title('Linear Regression Model for X1')
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)

plt.xlabel('Iterations')
plt.ylabel('Cost')

plt.show()

# %%
#run gradient descent function for X2
theta,cost_history = gradient_descent(X2,y,theta,alpha,iterations)

# %%
#scatter plot and linear regression plot for x2
plt.scatter(X2[:,1],y,color='red',marker='+',label ='X1 Data')
plt.plot(X2[:,1], X2.dot(theta), color='green', label='Linear Regression')

plt.grid(True)
plt.xlabel('X2')
plt.ylabel('y')
plt.title('Linear Regression Model for X2')
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)

plt.xlabel('Iterations')
plt.ylabel('Cost')

plt.show()

# %%
#run gradient descent function for X3
theta,cost_history = gradient_descent(X3,y,theta,alpha,iterations)

# %%
#scatter plot and linear regression plot for x3
plt.scatter(X3[:,1],y,color='red',marker='+',label ='X1 Data')
plt.plot(X3[:,1], X3.dot(theta), color='green', label='Linear Regression')

plt.grid(True)
plt.xlabel('X3')
plt.ylabel('y')
plt.title('Linear Regression Model for X3')
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)

plt.xlabel('Iterations')
plt.ylabel('Cost')

plt.show()

# %%
#problem 2 multiple variables

theta = [0.,0.,0.,0.]
iterations = 1000
alpha = 0.01

#set crv to a matrix capable of operation
X=np.hstack((X_0,X_1,X_2,X_3))


#gradient descent of X
theta,cost_history = gradient_descent(X,y,theta,alpha,iterations)

X_linear = X.dot(theta)

plt.plot(X, X.dot(theta), color='green', label='Linear Regression')

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)

plt.xlabel('Iterations')
plt.ylabel('Cost')

plt.show()

# %%
print(theta)

a1 = [1,1,1,1]
a2 = [1,2,0,4]
a3 = [1,3,2,1]

print('y1 = ', (a1*theta).sum())
print('y2 = ', (a2*theta).sum())
print('y3 = ', (a3*theta).sum())
# Out:
# [ 3.39929705 -1.73320582  0.84898275  0.0150737 ]
# y1 =  2.530147672070225
# y2 =  -0.006819802878978258
# y3 =  -0.08728122605119663
